# %% [markdown]
# https://medium.datadriveninvestor.com/using-python-to-collect-earnings-data-from-the-alpha-vantage-api-562c9c5ddbff

# %% [markdown]
# # Get earnings estimates for Stock market

# %%
BASE_URL = r"https://www.alphavantage.co/query?"

# %%
from io import BytesIO
import requests
import time
import pandas as pd

def earnings_calendar_api(api_key, horizon, symbol=None):
    if symbol is not None:
        url = f'{BASE_URL}function=EARNINGS_CALENDAR&symbol={symbol}&horizon={horizon}&apikey={api_key}'
        response = requests.get(url)
    else:
        url = f"{BASE_URL}function=EARNINGS_CALENDAR&horizon={horizon}&apikey={api_key}"
        response = requests.get(url)

    return pd.read_csv(BytesIO(response.content))

API_KEY = "INSERT_YOUR_API_KEY_HERE"
horizon=["3month","6month","12month"]
earnings_calendar_api(API_KEY,horizon[0])
# Out:
#      symbol                         name  reportDate fiscalDateEnding  \
# 0         A     Agilent Technologies Inc  2021-11-22       2021-10-31
# 1        AA                   Alcoa Corp  2022-01-18       2021-12-31
# 2       AAL  American Airlines Group Inc  2022-01-26       2021-12-31
# 3     AAMMF                        AAMMF  2021-11-24       2021-09-30
# 4       AAP       Advance Auto Parts Inc  2021-11-15       2021-09-30
# ...     ...                          ...         ...              ...
# 2766     ZS                  Zscaler Inc  2021-12-01       2021-10-31
# 2767   ZSAN           Zosano Pharma Corp  2021-11-11       2021-09-30
# 2768    ZTO     ZTO Express (Cayman) Inc  2021-11-17       2021-09-30
# 2769   ZUMZ                   Zumiez Inc  2021-12-01       2021-11-30
# 2770    ZUO          Zuora Inc - Class A  2021-12-01       2021-10-31
#
#       estimate currency
# 0         1.17      USD
# 1         2.27      USD
# 2        -1.74      USD
# 3          NaN      USD
# ...

# %% [markdown]
# # Get Balance Sheet in Python

# %% [markdown]
# **website to get the finiancial statement data**
#
# "https://site.financialmodelingprep.com/developer/docs"

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ### Reading `json` formate from the web and converting the ouctome into a dataframe
#
# https://towardsdatascience.com/how-to-convert-json-into-a-pandas-dataframe-100b2ae1e0d8

# %%
url = 'https://financialmodelingprep.com/api/v3/income-statement/AAPL?limit=120&apikey=484ef53efa76721588719d6741d9fb2b'
df = pd.read_json(url)

# %%
df
# Out:
#          date symbol reportedCurrency     cik fillingDate  \
# 0  2021-09-25   AAPL              USD  320193  2021-10-29
# 1  2020-09-26   AAPL              USD  320193  2020-10-30
# 2  2019-09-28   AAPL              USD  320193  2019-10-31
# 3  2018-09-29   AAPL              USD  320193  2018-11-05
# 4  2017-09-30   AAPL              USD  320193  2017-11-03
# 5  2016-09-24   AAPL              USD  320193  2016-10-26
# 6  2015-09-26   AAPL              USD  320193  2015-10-28
# 7  2014-09-27   AAPL              USD  320193  2014-10-27
# 8  2013-09-28   AAPL              USD  320193  2013-10-30
# 9  2012-09-29   AAPL              USD  320193  2012-10-31
# 10 2011-09-24   AAPL              USD  320193  2011-10-26
# 11 2010-09-25   AAPL              USD  320193  2010-10-27
# 12 2009-09-26   AAPL              USD  320193  2009-10-27
# 13 2008-09-27   AAPL              USD  320193  2008-11-05
# 14 2007-09-29   AAPL              USD  320193  2007-11-15
# ...

# %%
df = df.T
df.columns = df.iloc[0]
df = df.iloc[1:]

# %%
df
# Out:
# date                                                                            2021-09-25  \
# symbol                                                                                AAPL
# reportedCurrency                                                                       USD
# cik                                                                                 320193
# fillingDate                                                                     2021-10-29
# acceptedDate                                                           2021-10-28 18:04:28
# calendarYear                                                                          2021
# period                                                                                  FY
# revenue                                                                       365817000000
# costOfRevenue                                                                 212981000000
# ...

# %%
cols = df.columns
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')

# %%
df
# Out:
# date                                       2021-09-25    2020-09-26  \
# date                                              NaN           NaN
# symbol                                            NaN           NaN
# reportedCurrency                                  NaN           NaN
# cik                                      3.201930e+05  3.201930e+05
# fillingDate                                       NaN           NaN
# acceptedDate                                      NaN           NaN
# calendarYear                             2.021000e+03  2.020000e+03
# period                                            NaN           NaN
# revenue                                  3.658170e+11  2.745150e+11
# costOfRevenue                            2.129810e+11  1.695590e+11
# grossProfit                              1.528360e+11  1.049560e+11
# grossProfitRatio                         4.177936e-01  3.823325e-01
# researchAndDevelopmentExpenses           2.191400e+10  1.875200e+10
# ...
